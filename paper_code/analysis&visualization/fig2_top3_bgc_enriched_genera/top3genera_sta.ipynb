# %%
import pandas as pd

input_csv_file = "analysis/top3BGCrichedGenera/data/DataS1.8BGC.csv"
input_df = pd.read_csv(input_csv_file, sep=",", header=0)
input_df.shape
# Out:
# (175321, 22)

# %%
input_df = input_df[input_df['sum'] >= 20]
input_df.shape
# Out:
# (6062, 22)

# %%
grouped = (
    input_df
    .groupby(['phylum', 'genus'])['sum']
    .agg(
        mean_sum     = 'mean',
        sum_std      = 'std',
        genome_count = 'count'
    )
    .reset_index()
)

grouped
# Out:
#                 phylum                 genus   mean_sum    sum_std  \
# 0    p__Actinobacteria  g__Actinoalloteichus  30.500000  15.003333
# 1    p__Actinobacteria      g__Actinocrispum  54.000000        NaN
# 2    p__Actinobacteria   g__Actinokineospora  34.666667   8.094143
# 3    p__Actinobacteria       g__Actinomadura  27.285714   5.529144
# 4    p__Actinobacteria    g__Actinophytocola  38.400000   8.264381
# ..                 ...                   ...        ...        ...
# 126  p__Proteobacteria           g__Serratia  22.000000        NaN
# 127  p__Proteobacteria      g__Sinorhizobium  22.000000   1.000000
# 128  p__Proteobacteria          g__Sorangium  38.400000   6.148170
# 129  p__Proteobacteria        g__Stigmatella  31.666667   6.429101
# 130  p__Proteobacteria        g__Xanthomonas  25.000000   1.414214
#
#      genome_count
# 0               6
# 1               1
# 2              12
# 3               7
# 4               5
# ..            ...
# 126             1
# 127             3
# 128             5
# 129             3
# 130             2
#
# [131 rows x 5 columns]

# %%
filtered_grouped = grouped[
    (grouped['sum_std'] <= 15) &
    (grouped['genome_count'] >= 5) &
    (grouped['mean_sum'] >= 10)
].reset_index(drop=True).sort_values(by='mean_sum', ascending=False)

filtered_grouped
# Out:
#                phylum                 genus   mean_sum    sum_std  \
# 26  p__Proteobacteria      g__Corallococcus  53.720930  13.570496
# 5   p__Actinobacteria  g__Kibdelosporangium  49.714286   2.429972
# 6   p__Actinobacteria      g__Kitasatospora  38.675676  11.785240
# 33  p__Proteobacteria          g__Sorangium  38.400000   6.148170
# 2   p__Actinobacteria    g__Actinophytocola  38.400000   8.264381
# 19  p__Actinobacteria       g__Streptomyces  37.660987  12.971623
# 16  p__Actinobacteria      g__Saccharothrix  35.631579   7.725934
# 0   p__Actinobacteria   g__Actinokineospora  34.666667   8.094143
# 3   p__Actinobacteria      g__Amycolatopsis  33.864583  13.407476
# 18  p__Actinobacteria  g__Streptacidiphilus  32.777778   6.960204
# 7   p__Actinobacteria            g__Lentzea  32.500000   5.898260
# 27  p__Proteobacteria         g__Myxococcus  32.431818  12.445972
# 4   p__Actinobacteria            g__Frankia  32.375000   6.163062
# 12  p__Actinobacteria           g__Nocardia  29.818605   6.658536
# 15  p__Actinobacteria  g__Saccharopolyspora  29.000000   6.442049
# 25  p__Proteobacteria       g__Burkholderia  28.598326   4.702446
# 24      p__Firmicutes      g__Paenibacillus  28.150000   7.419828
# 20   p__Bacteroidetes       g__Chitinophaga  27.684211   5.831453
# 29  p__Proteobacteria       g__Photorhabdus  27.600000   8.757219
# 17  p__Actinobacteria        g__Salinispora  27.400000   4.794734
# 1   p__Actinobacteria       g__Actinomadura  27.285714   5.529144
# 8   p__Actinobacteria     g__Micromonospora  27.029412   7.477179
# 21   p__Cyanobacteria             g__Nostoc  26.705882   5.535174
# 9   p__Actinobacteria      g__Mycobacterium  26.362434   5.978597
# 14  p__Actinobacteria        g__Rhodococcus  26.161677   5.583234
# 31  p__Proteobacteria        g__Pseudomonas  24.853933   6.357962
# 30  p__Proteobacteria  g__Pseudoalteromonas  24.750000   2.121320
# 13  p__Actinobacteria       g__Nocardiopsis  24.200000   3.583915
# 28  p__Proteobacteria   g__Paraburkholderia  24.200000   3.962323
# 23      p__Firmicutes      g__Brevibacillus  24.000000   2.000000
# 11  p__Actinobacteria  g__Mycolicibacterium  23.475000   2.679337
# 32  p__Proteobacteria          g__Ralstonia  23.200000   2.387467
# 22      p__Firmicutes           g__Bacillus  23.163934   3.421405
# 10  p__Actinobacteria    g__Mycobacteroides  21.540000   1.049192
#
#     genome_count
# 26            43
# 5              7
# 6             37
# 33             5
# 2              5
# 19          1702
# 16            19
# 0             12
# 3             96
# 18             9
# 7             20
# 27            44
# 4             16
# 12           215
# 15            17
# 25          2151
# 24            40
# 20            19
# 29            55
# 17            20
# 1              7
# 8             34
# 21            34
# 9            378
# 14           167
# 31           356
# 30             8
# 13            10
# 28             5
# 23             5
# 11            40
# 32             5
# 22            61
# 10           250

# %%
# 假设 df_sorted 已经按 ['phylum','mean_sum'] 排好序，且列名分别为 'phylum', 'genus', 'mean_sum'
target_phylum_genus = {}  # 最终结果：{ phylum1: [genus1, genus2, genus3], phylum2: […], … }

for _, row in filtered_grouped.iterrows():
    ph = row['phylum']
    gen = row['genus']
    
    # 如果这个 phylum 尚未加入，且已满 6 个 phylum，则跳过
    if ph not in target_phylum_genus:
        if len(target_phylum_genus) >= 6:
            continue
        # 新 phylum，初始化空 list
        target_phylum_genus[ph] = []
    
    # 对于已加入的 phylum，若其 genus 数量 < 3，则添加
    if len(target_phylum_genus[ph]) < 3:
        target_phylum_genus[ph].append(gen)
    
    # 提前退出：当已收集到 6×3=18 条组合时，整个循环可以结束
    total = sum(len(glist) for glist in target_phylum_genus.values())
    if total >= 6 * 3:
        break

# 打印结果检验
# 收集所有 (phylum, genus) 对
pairs = [(ph, g) for ph, gens in target_phylum_genus.items() for g in gens]

# 从 filtered_grouped 中筛选出这些行
result_df = filtered_grouped[
    filtered_grouped.apply(lambda r: (r['phylum'], r['genus']) in pairs, axis=1)
].reset_index(drop=True)
result_df.to_csv('analysis/top3BGCrichedGenera/data/top_phylum_genus_mean.csv', index=False)
result_df
# Out:
#                phylum                 genus   mean_sum    sum_std  \
# 0   p__Proteobacteria      g__Corallococcus  53.720930  13.570496
# 1   p__Actinobacteria  g__Kibdelosporangium  49.714286   2.429972
# 2   p__Actinobacteria      g__Kitasatospora  38.675676  11.785240
# 3   p__Proteobacteria          g__Sorangium  38.400000   6.148170
# 4   p__Actinobacteria    g__Actinophytocola  38.400000   8.264381
# 5   p__Proteobacteria         g__Myxococcus  32.431818  12.445972
# 6       p__Firmicutes      g__Paenibacillus  28.150000   7.419828
# 7    p__Bacteroidetes       g__Chitinophaga  27.684211   5.831453
# 8    p__Cyanobacteria             g__Nostoc  26.705882   5.535174
# 9       p__Firmicutes      g__Brevibacillus  24.000000   2.000000
# 10      p__Firmicutes           g__Bacillus  23.163934   3.421405
#
#     genome_count
# 0             43
# 1              7
# 2             37
# 3              5
# 4              5
# 5             44
# 6             40
# 7             19
# 8             34
# 9              5
# 10            61

# %%
_df = result_df[['phylum','genus']]

# 2. inner-merge 或者 .isin 过滤
filtered_df = input_df.merge(_df, on=['phylum','genus'], how='inner')

# 3. 保存
filtered_df.to_csv('analysis/top3BGCrichedGenera/data/top3genera.csv', index=False)

filtered_df
# Out:
#     assembly_accession  CheckM completeness  CheckM contamination  \
# 0      GCF_002082585.1                99.96                  0.38
# 1      GCF_004364325.1                99.92                  2.84
# 2      GCF_017876405.1                99.75                  1.19
# 3      GCF_000520795.1                99.72                  0.19
# 4      GCF_000612225.1                99.72                  2.14
# ..                 ...                  ...                   ...
# 295    GCF_016757455.1                93.90                  2.69
# 296    GCF_014222275.1                93.81                  0.91
# 297    GCF_014698115.1                93.26                  3.16
# 298    GCF_000696185.1                93.12                  0.62
# 299    GCF_006636205.1                91.48                  1.75
#
#            16S_ID    taxid   assembly_level       kindom             phylum  \
# 0    refseq136643    68173  Complete Genome  k__Bacteria  p__Actinobacteria
# 1     refseq70366   502181           Contig  k__Bacteria  p__Actinobacteria
# 2     refseq22918  1365924           Contig  k__Bacteria  p__Actinobacteria
# 3    refseq159969  1333863           Contig  k__Bacteria      p__Firmicutes
# 4    refseq162225  1444314           Contig  k__Bacteria      p__Firmicutes
# ..            ...      ...              ...          ...                ...
# 295  refseq185580  2804502           Contig  k__Bacteria      p__Firmicutes
# 296   refseq60516  2681306           Contig  k__Bacteria   p__Cyanobacteria
# 297  refseq180410  2692844           Contig  k__Bacteria   p__Cyanobacteria
# 298   refseq17595  1348663         Scaffold  k__Bacteria  p__Actinobacteria
# 299   refseq55317  2567942           Contig  k__Bacteria  p__Actinobacteria
#
#                                    class                 order  ...  \
# 0                       c__Actinomycetia   o__Streptomycetales  ...
# 1                       c__Actinomycetia  o__Pseudonocardiales  ...
# 2                       c__Actinomycetia  o__Pseudonocardiales  ...
# 3                             c__Bacilli         o__Bacillales  ...
# 4                             c__Bacilli         o__Bacillales  ...
# ..                                   ...                   ...  ...
# 295                           c__Bacilli         o__Bacillales  ...
# 296  c__unclassified Cyanobacteria class         o__Nostocales  ...
# 297  c__unclassified Cyanobacteria class         o__Nostocales  ...
# 298                     c__Actinomycetia   o__Streptomycetales  ...
# 299                     c__Actinomycetia   o__Streptomycetales  ...
#
#                                species sum PKSI  PKSother  NRPS  RiPPs  \
# 0           s__Kitasatospora albolonga  38  0.0       3.0   7.0    6.0
# 1            s__Actinophytocola oryzae  42  6.0       2.0   6.0    5.0
# 2      s__Kibdelosporangium banguiense  46  3.0       0.0  11.0    8.0
# 3            s__Paenibacillus polymyxa  31  0.0       2.0  19.0    4.0
# 4           s__Paenibacillus ehimensis  27  0.0       1.0  17.0    2.0
# ..                                 ...  ..  ...       ...   ...    ...
# 295             s__Bacillus sp. RHFS18  46  0.0      21.0  19.0    1.0
# 296               s__Nostoc sp. UCD122  31  1.0       2.0   9.0    9.0
# 297            s__Nostoc sp. FACHB-973  28  2.0       3.0   8.0    4.0
# 298    s__Kitasatospora cheerisanensis  30  2.0       1.0   2.0   11.0
# 299  s__Kitasatospora sp. MMS16-CNU292  30  1.0       1.0   7.0    6.0
#
#      Saccharides  Terpene  PKS-NRP_Hybrids  Others
# 0            0.0      5.0              4.0    13.0
# 1            0.0      3.0              5.0    15.0
# 2            1.0      5.0              3.0    15.0
# 3            0.0      0.0              5.0     1.0
# 4            0.0      1.0              4.0     2.0
# ..           ...      ...              ...     ...
# 295          0.0      1.0              2.0     2.0
# 296          0.0      6.0              4.0     0.0
# 297          0.0      4.0              4.0     3.0
# 298          0.0      5.0              3.0     6.0
# 299          0.0      3.0              3.0     9.0
#
# [300 rows x 22 columns]
